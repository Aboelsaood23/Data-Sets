# %% [markdown]
# <a href="https://colab.research.google.com/github/Aboelsaood23/Data-Sets/blob/main/Google_ads_datset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Main Dimensions :**
# * Campaign Name
# * Campaign Status
# * Ad Type
# * Ad Id
# * Start Date

# %%
import pandas as pd
import numpy as np
import random
from datetime import datetime,timedelta
data ={
    "Campaign_Name":[],"Campaign_Status":[],"Ad_Type":[],"Ad_ID":[]
}
df =pd.DataFrame(data)
#let's assign values to this dataframe columns
df['Campaign_Name']=['sales','subscrition']
# repeat vales of cmapaign names
index_brand =0
df_repeated =pd.concat([df.loc[[index_brand]]]*156,ignore_index=True).append(df.drop(index_brand),ignore_index=True)
index_leads =156
df_repeated_2 =pd.concat([df_repeated.loc[[index_leads]]]*52,ignore_index=True).append(df_repeated.drop(index_leads),ignore_index=True)
df = df_repeated_2
#Campaign status
Campaign_Status=['Ended','Paused','Eligible','Pending']
np.random.shuffle(Campaign_Status)
df['Campaign_Status'] =df['Campaign_Status'].fillna(pd.Series(np.random.choice(Campaign_Status,size=len(df),p=[1/6,1/3,1/3,1/6])))

Ad_Type=['Search Ads','Shopping Ads','Google Shopping']
df['Ad_Type'] =df['Ad_Type'].fillna(pd.Series(np.random.choice(Ad_Type,size=len(df),p=[1/4,2/4,1/4])))
# add values to ad id to be like this AD_202391,AD_202392 and so on
start_value = "AD_202391"
df['Ad_ID'].fillna(pd.Series(range(len(df))).add(int(start_value[3:])).astype(str).radd("AD_"), inplace=True)
df

# create function to add date column
def generate_random_date():
    start_date = datetime(2023, 1, 9)
    end_date = datetime(2023, 12, 31)
    random_days = random.randint(0, (end_date - start_date).days)
    random_date = start_date + timedelta(days=random_days)
    return random_date

df['Start_Date'] = [generate_random_date() for _ in range(len(df))]
df
# Out:
# <ipython-input-40-80a44c8c6779>:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_repeated =pd.concat([df.loc[[index_brand]]]*156,ignore_index=True).append(df.drop(index_brand),ignore_index=True)
# <ipython-input-40-80a44c8c6779>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_repeated_2 =pd.concat([df_repeated.loc[[index_leads]]]*52,ignore_index=True).append(df_repeated.drop(index_leads),ignore_index=True)
#     Campaign_Name Campaign_Status          Ad_Type      Ad_ID Start_Date
# 0     subscrition          Paused     Shopping Ads  AD_202391 2023-05-15
# 1     subscrition        Eligible       Search Ads  AD_202392 2023-07-15
# 2     subscrition         Pending     Shopping Ads  AD_202393 2023-04-18
# 3     subscrition        Eligible     Shopping Ads  AD_202394 2023-06-29
# 4     subscrition        Eligible     Shopping Ads  AD_202395 2023-03-21
# ..            ...             ...              ...        ...        ...
# 203         sales          Paused  Google Shopping  AD_202594 2023-02-26
# 204         sales        Eligible     Shopping Ads  AD_202595 2023-10-17
# 205         sales         Pending  Google Shopping  AD_202596 2023-07-13
# 206         sales         Pending     Shopping Ads  AD_202597 2023-10-22
# 207         sales        Eligible     Shopping Ads  AD_202598 2023-11-30
#
# [208 rows x 5 columns]

# %% [markdown]
# ##**Demographic Targeting Dimensions :**
# * Gender
# * Age_Target
# * Location
# * Device

# %%
df['Gender'] =np.random.choice(['Male','Female'],size=len(df),p=[0.55,0.45])
df['Age_Target'] =np.random.choice(['18-25','25-35','35-40','45-60','60+'],size =len(df),p=[0.23,0.30,0.20,0.15,0.12])
df['Location'] =np.random.choice(["United States","Brazil","Germany","Australia","Nigeria","France","South Africa","China","Argentina","Canada","Egypt","Japan","New Zealand","Chile"],
                                 size=len(df),p=[0.035110782843004035,0.20773879848777385,0.02800972563880097,0.054192730040288836,0.042251959014462485,0.13120345167648875,0.08903091363761736,
                                                 0.07331957593686136,0.06391963030393041,0.062321639546332165,0.04532482876096884,0.09971462327413146,0.034623133081295644,0.03323820775804382])
df['Device'] =np.random.choice(['Desktop','Mobile','Tablet','Other'],size =len(df),p=[0.23,0.42,0.20,0.15])
df
# Out:
#     Campaign_Name Campaign_Status          Ad_Type      Ad_ID Start_Date  \
# 0     subscrition          Paused     Shopping Ads  AD_202391 2023-05-15
# 1     subscrition        Eligible       Search Ads  AD_202392 2023-07-15
# 2     subscrition         Pending     Shopping Ads  AD_202393 2023-04-18
# 3     subscrition        Eligible     Shopping Ads  AD_202394 2023-06-29
# 4     subscrition        Eligible     Shopping Ads  AD_202395 2023-03-21
# ..            ...             ...              ...        ...        ...
# 203         sales          Paused  Google Shopping  AD_202594 2023-02-26
# 204         sales        Eligible     Shopping Ads  AD_202595 2023-10-17
# 205         sales         Pending  Google Shopping  AD_202596 2023-07-13
# 206         sales         Pending     Shopping Ads  AD_202597 2023-10-22
# 207         sales        Eligible     Shopping Ads  AD_202598 2023-11-30
#
#      Gender Age_Target       Location   Device
# 0      Male      35-40         Brazil   Mobile
# 1      Male      25-35         Canada  Desktop
# 2      Male      18-25         Brazil   Tablet
# 3      Male      18-25   South Africa   Mobile
# 4    Female      45-60         Brazil   Mobile
# ..      ...        ...            ...      ...
# 203    Male      18-25          Japan   Mobile
# 204    Male      18-25        Germany   Tablet
# 205    Male      45-60  United States   Mobile
# 206  Female      45-60         Brazil    Other
# 207    Male      18-25         Brazil   Tablet
#
# [208 rows x 9 columns]

# %% [markdown]
# ##**Metics :**
#
#
# *  Amount_spent($)
# *  Impressions
# *  Clicks
# *  Conversions

# %%
df['Amount_Spent_$'] =np.random.uniform(100,150, size=len(df))
df['Impressions'] =(df['Amount_Spent_$']*20).astype(int)
df['Clicks'] =(df['Impressions']/(8*np.random.uniform(1,1.2))).astype(int)

#ctr = (total_impressions/total_Clicks)*100 "do the calculations on looker "
df['Conversions'] =(df['Clicks']/7).astype(int)

#Calculate value of all conversions
def multiply_conversion(row):
    if row['Ad_Type'] == 'Search Ads':
        return row['Conversions'] * 20
    elif row['Ad_Type'] == 'Shopping Ads':
        return row['Conversions'] * 35
    elif row['Ad_Type'] == 'Google Shopping':
        return row['Conversions'] * 32
    else:
        return None  # Handle other cases if necessary

df['Revenue_$'] = df.apply(multiply_conversion, axis=1)
#Totoal Convesion values =sum(Revenue)  "do this calcculation on looker"
#covnersion rates= (Cinversions/Clicks)*100 "do this calculation on looker"
#cost per conversion =(total_Cost(amount_spent_$)/Conversions) "do this calcaulation on looker"
#RoAS"Rturn on Ad Spend" : total_revenue/total_cost "do this calculation on looker"
#CPC "Cost per Click": totalcost/number of click "do on looker"
#cost per mile "CPM" :total_cost/(numer of impressions/1000) "looker"
df
# Out:
#     Campaign_Name Campaign_Status          Ad_Type      Ad_ID Start_Date  \
# 0     subscrition          Paused     Shopping Ads  AD_202391 2023-05-15
# 1     subscrition        Eligible       Search Ads  AD_202392 2023-07-15
# 2     subscrition         Pending     Shopping Ads  AD_202393 2023-04-18
# 3     subscrition        Eligible     Shopping Ads  AD_202394 2023-06-29
# 4     subscrition        Eligible     Shopping Ads  AD_202395 2023-03-21
# ..            ...             ...              ...        ...        ...
# 203         sales          Paused  Google Shopping  AD_202594 2023-02-26
# 204         sales        Eligible     Shopping Ads  AD_202595 2023-10-17
# 205         sales         Pending  Google Shopping  AD_202596 2023-07-13
# 206         sales         Pending     Shopping Ads  AD_202597 2023-10-22
# 207         sales        Eligible     Shopping Ads  AD_202598 2023-11-30
#
#      Gender Age_Target       Location   Device  Amount_Spent_$  Impressions  \
# 0      Male      35-40         Brazil   Mobile      145.693060         2913
# 1      Male      25-35         Canada  Desktop      118.325836         2366
# 2      Male      18-25         Brazil   Tablet      148.936914         2978
# 3      Male      18-25   South Africa   Mobile      141.812633         2836
# 4    Female      45-60         Brazil   Mobile      126.830351         2536
# ..      ...        ...            ...      ...             ...          ...
# 203    Male      18-25          Japan   Mobile      138.517873         2770
# 204    Male      18-25        Germany   Tablet      117.435474         2348
# 205    Male      45-60  United States   Mobile      109.112383         2182
# 206  Female      45-60         Brazil    Other      113.070488         2261
# 207    Male      18-25         Brazil   Tablet      135.122664         2702
#
#      Clicks  Conversions  Revenue_$
# 0       310           44       1540
# 1       252           36        720
# 2       317           45       1575
# 3       302           43       1505
# 4       270           38       1330
# ..      ...          ...        ...
# 203     295           42       1344
# 204     250           35       1225
# 205     232           33       1056
# 206     241           34       1190
# 207     288           41       1435
#
# [208 rows x 14 columns]

# %% [markdown]
# ### **Shuffle dataset and download it**

# %%
from google.colab import files
#shuffle dataframe, keeping same index order
df= df.iloc[df.sample(frac =1).index].reset_index(drop =False)
df= df.drop(columns=['index'])
# convert to csv
df.to_csv('Google_dataset.csv', index=False)
#download csv
files.download("Google_dataset.csv")
df
# Out:
#     Campaign_Name Campaign_Status          Ad_Type      Ad_ID Start_Date  \
# 0           sales           Ended       Search Ads  AD_202576 2023-10-21
# 1     subscrition        Eligible     Shopping Ads  AD_202431 2023-08-18
# 2           sales           Ended     Shopping Ads  AD_202519 2023-04-23
# 3           sales           Ended     Shopping Ads  AD_202546 2023-02-21
# 4     subscrition        Eligible  Google Shopping  AD_202405 2023-10-29
# ..            ...             ...              ...        ...        ...
# 203         sales        Eligible     Shopping Ads  AD_202566 2023-05-04
# 204   subscrition        Eligible       Search Ads  AD_202433 2023-07-18
# 205         sales        Eligible       Search Ads  AD_202450 2023-02-28
# 206         sales          Paused  Google Shopping  AD_202591 2023-12-18
# 207         sales           Ended     Shopping Ads  AD_202585 2023-08-30
#
#      Gender Age_Target      Location   Device  Amount_Spent_$  Impressions  \
# 0    Female      18-25         Egypt   Mobile      139.775500         2795
# 1    Female        60+     Australia    Other      115.086933         2301
# 2      Male      18-25        Brazil  Desktop      140.821433         2816
# 3      Male        60+        Brazil    Other      147.482244         2949
# 4    Female      25-35     Australia  Desktop      122.652069         2453
# ..      ...        ...           ...      ...             ...          ...
# 203  Female        60+  South Africa  Desktop      110.327325         2206
# 204  Female        60+        Brazil   Mobile      123.788719         2475
# 205    Male      25-35       Germany    Other      114.557530         2291
# 206  Female      18-25         China  Desktop      127.694249         2553
# 207    Male      45-60        Brazil   Mobile      121.265524         2425
#
#      Clicks  Conversions  Revenue_$
# 0       298           42        840
# 1       245           35       1225
# 2       300           42       1470
# 3       314           44       1540
# 4       261           37       1184
# ..      ...          ...        ...
# 203     235           33       1155
# 204     263           37        740
# 205     244           34        680
# 206     272           38       1216
# 207     258           36       1260
#
# [208 rows x 14 columns]
